# %% [markdown]
# # Inspeção Inicial dos Dados Financeiros
#
# ## Objetivo
#
# Realizar a **inspeção inicial** dos dados financeiros antes de qualquer limpeza ou análise.
#
# ### Tabelas Principais:
# - `olist_order_payments_dataset.csv` - Dados de pagamentos
# - `olist_order_items_dataset.csv` - Itens dos pedidos (preço e frete)
# - `olist_orders_dataset.csv` - Informações dos pedidos
#
# ### Etapas:
# 1. Configuração e carregamento dos dados
# 2. Inspeção da estrutura de cada tabela
# 3. Análise de valores nulos
# 4. Identificação de problemas nos dados
# 5. Conclusões e próximos passos

# %% [markdown]
# ---
#
# ## Configurações Iniciais

# %%
# ========================================================================
# ETL - ANÁLISE FINANCEIRA E PAGAMENTOS
# Projeto Integrador - SENAC - Pessoa 6
# ========================================================================
# TRANSFORM - (Inspeção Inicial dos Dados)
# Objetivo: Carregar e entender a estrutura dos dados antes de limpar
# ========================================================================

import pandas as pd
import numpy as np
from datetime import datetime
import os
import warnings
warnings.filterwarnings('ignore')
# O import de warnings é só pra remover alguns avisos que podem aparecer
# Serve exclusivamente pra limpeza e organização do output

# %%
# ============================================================================
# CONFIGURAÇÃO DE CAMINHOS
# ============================================================================

# Descobre automaticamente a raiz do projeto
# Usando as funçõs OS pra garantir compatibilidade entre sistemas operacionais

# Pega o arquivo atual
from pathlib import Path
BASE_PATH = Path.cwd()

# Sobe na hierarquia de pastas até encontrar a raiz do projeto
while BASE_PATH.name != "PROJETO-INTEGRADOR--GRUPO-37" and BASE_PATH.parent != BASE_PATH:
    BASE_PATH = BASE_PATH.parent

# Caminhos dos dados
RAW_DATA_PATH = BASE_PATH / "data" / "raw"
CLEANED_DATA_PATH = BASE_PATH / "data" / "cleaned" / "pessoa_6"

print("=" * 80)
print("ETAPA 1: CONFERÊNCIA DE CAMINHOS")
print("=" * 80, "\n")
# Mostrar os caminhos (para verificar)
print(f"─ Raiz do projeto: {BASE_PATH}")
print(f"─ Dados brutos: {RAW_DATA_PATH}")
print(f"─ Dados limpos: {CLEANED_DATA_PATH}\n")

# ============================================================================
# CONFIGURAÇÃO DA VISUALIZAÇÃO DE DADOS
# ============================================================================

# Mostrar todas as colunas, sem o corte no meio pra caber no terminal.
pd.set_option('display.max_columns', None)
# Largura automática.
pd.set_option('display.width', None)
# Limite de caracteres por célula, padronizar a visualização.
pd.set_option('display.max_colwidth', 15)
# Out:
# ================================================================================
# ETAPA 1: CONFERÊNCIA DE CAMINHOS
# ================================================================================
#
# ─ Raiz do projeto: c:\Users\lucas\Documents\Projetos\SENAC - Projeto Integrador\PROJETO-INTEGRADOR--GRUPO-37
# ─ Dados brutos: c:\Users\lucas\Documents\Projetos\SENAC - Projeto Integrador\PROJETO-INTEGRADOR--GRUPO-37\data\raw
# ─ Dados limpos: c:\Users\lucas\Documents\Projetos\SENAC - Projeto Integrador\PROJETO-INTEGRADOR--GRUPO-37\data\cleaned\pessoa_6

# %% [markdown]
# ---
#
# ## Carregamento dos Dados

# %%
# ============================================================================
# CARREGAMENTO DOS DADOS
# ============================================================================

# Carregando a tabela de pagamentos
df_payments = pd.read_csv(os.path.join(RAW_DATA_PATH, "olist_order_payments_dataset.csv"))

# Carregando a tabela de itens de pedido
df_order_items = pd.read_csv(os.path.join(RAW_DATA_PATH, "olist_order_items_dataset.csv"))

# Carregando a tabela de pedidos
df_orders = pd.read_csv(os.path.join(RAW_DATA_PATH, "olist_orders_dataset.csv"))

# ============================================================================
# VISUALIZANDO OS NOSSOS DADOS
# ============================================================================

print("=" * 80)
print("ETAPA 2: INSPEÇÃO INICIAL DOS DADOS FINANCEIROS")
print("=" * 80)

print(f"   # {len(df_payments):,} registros | {len(df_payments.columns)} colunas")
print(f"   # {len(df_order_items):,} registros | {len(df_order_items.columns)} colunas")
print(f"   # {len(df_orders):,} registros | {len(df_orders.columns)} colunas", "\n")

# ============================================================================
# ANÁLISE DE VALORES NULOS
# ============================================================================

def analisar_nulos(df, nome_tabela):
    nulos = df.isnull().sum()
    total_linhas = len(df)
    percentual = (nulos / total_linhas * 100).round(2)
    
    # Loop pra conferir todas as colunas
    for coluna in df.columns:
        contagem_nulos = nulos[coluna]
        perc_nulos = percentual[coluna]
        print(f"Coluna: {coluna} - Total de valores nulos: {contagem_nulos} - Percentual: {perc_nulos}%")
# Out:
# ================================================================================
# ETAPA 2: INSPEÇÃO INICIAL DOS DADOS FINANCEIROS
# ================================================================================
#    # 103,886 registros | 5 colunas
#    # 112,650 registros | 7 colunas
#    # 99,441 registros | 8 colunas

# %% [markdown]
# ---
#
# ## Análise do Dataframe - PAYMENTS

# %%
# ============================================================================
# ANÁLISE DO DATAFRAME - payments
# ============================================================================

print("=" * 80)
print("ETAPA 2.1: ANÁLISE DO DATAFRAME - payments")
print("=" * 80)
# O Shape é pra gerar a tupla dos dados do nosso dataset.
# O 0 são as linhas, o 1 são as colunas.
print(f"Dimensões da tabela: {df_payments.shape[0]:,} linhas x {df_payments.shape[1]} colunas", "\n")
# Aqui, chamar a função de analisar nulos.
analisar_nulos(df_payments, "payments")
print("\n" , "Colunas e tipos de dados:")
print("-" * 80)
print(df_payments.dtypes, "\n")
print("\n", "Primeiras cinco linhas:")
print("-" * 80)
# O head() automaticamente puxa 5 linhas
print(df_payments.head())

# Detalhamento maior, visando os dashboards
print("\n", "Tipos de Pagamento:")
print("-" * 80)
print(df_payments['payment_type'].value_counts())

print("\n", "Valores de Pagamento - Distribuição:")
print("-" * 80)
# A função .2f é mais simples do que formatar tudo como float.
print(f"Mínimo: R$ {df_payments['payment_value'].min():.2f}")
print(f"Máximo: R$ {df_payments['payment_value'].max():.2f}")
print(f"Média: R$ {df_payments['payment_value'].mean():.2f}")
print(f"Mediana: R$ {df_payments['payment_value'].median():.2f}")

print("\n", "Parcelas - Top 10:")
print("-" * 80)
print(df_payments['payment_installments']
      .value_counts()
      .head(10)
      .sort_values(ascending=False))
# Out:
# ================================================================================
# ETAPA 2.1: ANÁLISE DO DATAFRAME - payments
# ================================================================================
# Dimensões da tabela: 103,886 linhas x 5 colunas
#
# Coluna: order_id - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: payment_sequential - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: payment_type - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: payment_installments - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: payment_value - Total de valores nulos: 0 - Percentual: 0.0%
#
#  Colunas e tipos de dados:
# --------------------------------------------------------------------------------
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object
#
#
#  Primeiras cinco linhas:
# --------------------------------------------------------------------------------
#          order_id  payment_sequential payment_type  payment_installments  \
# 0  b81ef226f3f...               1      credit_card               8
# 1  a9810da8291...               1      credit_card               1
# 2  25e8ea4e933...               1      credit_card               1
# 3  ba78997921b...               1      credit_card               8
# 4  42fdf880ba1...               1      credit_card               2
#
#    payment_value
# 0          99.33
# 1          24.39
# 2          65.71
# 3         107.78
# 4         128.45
#
#  Tipos de Pagamento:
# --------------------------------------------------------------------------------
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64
#
#  Valores de Pagamento - Distribuição:
# --------------------------------------------------------------------------------
# Mínimo: R$ 0.00
# Máximo: R$ 13664.08
# Média: R$ 154.10
# Mediana: R$ 100.00
#
#  Parcelas - Top 10:
# --------------------------------------------------------------------------------
# payment_installments
# 1     52546
# 2     12413
# 3     10461
# 4      7098
# 10     5328
# 5      5239
# 8      4268
# 6      3920
# 7      1626
# 9       644
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ## Análise do Dataframe - ORDER_ITEMS

# %%
# ============================================================================
# ANÁLISE DO DATAFRAME - order_items
# ============================================================================

print("=" * 80)
print("ETAPA 2.2: ANÁLISE DO DATAFRAME - order_items")
print("=" * 80)
print(f"Dimensões da tabela: {df_order_items.shape[0]} linhas x {df_order_items.shape[1]} colunas\n")
analisar_nulos(df_order_items, "order_items")
print("\n" , "Colunas e tipos de dados:")
print("-" * 80)
print(df_order_items.dtypes, "\n")
print("\n", "Primeiras cinco linhas:")
print("-" * 80)
print(df_order_items.head())

print("\n","Preços - Distribuição:")
print("-" * 80)

# A função .2f é mais simples do que formatar tudo como float.
print(f"Mínimo: R$ {df_order_items['price'].min():.2f}")
print(f"Máximo: R$ {df_order_items['price'].max():.2f}")
print(f"Média: R$ {df_order_items['price'].mean():.2f}")
print(f"Mediana: R$ {df_order_items['price'].median():.2f}")

print("\n","Frete - Distribuição:")
print("-" * 80)
print(f"Mínimo: R$ {df_order_items['freight_value'].min():.2f}")
print(f"Máximo: R$ {df_order_items['freight_value'].max():.2f}")
print(f"Média: R$ {df_order_items['freight_value'].mean():.2f}")
print(f"Mediana: R$ {df_order_items['freight_value'].median():.2f}")
# Out:
# ================================================================================
# ETAPA 2.2: ANÁLISE DO DATAFRAME - order_items
# ================================================================================
# Dimensões da tabela: 112650 linhas x 7 colunas
#
# Coluna: order_id - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: order_item_id - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: product_id - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: seller_id - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: shipping_limit_date - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: price - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: freight_value - Total de valores nulos: 0 - Percentual: 0.0%
#
#  Colunas e tipos de dados:
# --------------------------------------------------------------------------------
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object
#
#
#  Primeiras cinco linhas:
# --------------------------------------------------------------------------------
#          order_id  order_item_id      product_id       seller_id  \
# 0  00010242fe8...              1  4244733e06e...  48436dade18...
# 1  00018f77f2f...              1  e5f2d52b802...  dd7ddc04e1b...
# 2  000229ec398...              1  c777355d18b...  5b51032eddd...
# 3  00024acbcdf...              1  7634da152a4...  9d7a1d34a50...
# 4  00042b26cf5...              1  ac6c3623068...  df560393f3a...
#
#   shipping_limit_date   price  freight_value
# 0  2017-09-19 ...       58.90          13.29
# 1  2017-05-03 ...      239.90          19.93
# 2  2018-01-18 ...      199.00          17.87
# 3  2018-08-15 ...       12.99          12.79
# 4  2017-02-13 ...      199.90          18.14
#
#  Preços - Distribuição:
# --------------------------------------------------------------------------------
# Mínimo: R$ 0.85
# Máximo: R$ 6735.0
# Média: R$ 120.65373901464716
# Mediana: R$ 74.99
#
#  Frete - Distribuição:
# --------------------------------------------------------------------------------
# Mínimo: R$ 0.00
# Máximo: R$ 409.68
# Média: R$ 19.99
# Mediana: R$ 16.26

# %% [markdown]
# ---
#
# ## Análise do Dataframe - ORDERS

# %%
# ============================================================================
# ANÁLISE DO DATAFRAME - orders
# ============================================================================

print("=" * 80)
print("ETAPA 2.3: ANÁLISE DO DATAFRAME - orders")
print("=" * 80)
print(f"Dimensões da tabela: {df_orders.shape[0]:,} linhas x {df_orders.shape[1]} colunas\n")
analisar_nulos(df_orders, "orders")
print("\n" , "Colunas e tipos de dados:")
print("-" * 80)
print(df_orders.dtypes, "\n")
print("\n", "Primeiras cinco linhas:")
print("-" * 80)
# O head() automaticamente puxa 5 linhas
print(df_orders.head())
print("\n" ,"Status dos Pedidos:")
print("-" * 80)
print(df_orders['order_status'].value_counts())
# Out:
# ================================================================================
# ETAPA 2.3: ANÁLISE DO DATAFRAME - orders
# ================================================================================
# Dimensões da tabela: 99,441 linhas x 8 colunas
#
# Coluna: order_id - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: customer_id - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: order_status - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: order_purchase_timestamp - Total de valores nulos: 0 - Percentual: 0.0%
# Coluna: order_approved_at - Total de valores nulos: 160 - Percentual: 0.16%
# Coluna: order_delivered_carrier_date - Total de valores nulos: 1783 - Percentual: 1.79%
# Coluna: order_delivered_customer_date - Total de valores nulos: 2965 - Percentual: 2.98%
# Coluna: order_estimated_delivery_date - Total de valores nulos: 0 - Percentual: 0.0%
#
#  Colunas e tipos de dados:
# --------------------------------------------------------------------------------
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object
#
#
#  Primeiras cinco linhas:
# --------------------------------------------------------------------------------
#          order_id     customer_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc...  9ef432eb625...    delivered  2017-10-02 ...
# 1  53cdb2fc8bc...  b0830fb4747...    delivered  2018-07-24 ...
# 2  47770eb9100...  41ce2a54c0b...    delivered  2018-08-08 ...
# 3  949d5b44dbf...  f88197465ea...    delivered  2017-11-18 ...
# 4  ad21c59c084...  8ab97904e6d...    delivered  2018-02-13 ...
#
#   order_approved_at order_delivered_carrier_date  \
# 0  2017-10-02 ...    2017-10-04 ...
# 1  2018-07-26 ...    2018-07-26 ...
# 2  2018-08-08 ...    2018-08-08 ...
# 3  2017-11-18 ...    2017-11-22 ...
# 4  2018-02-13 ...    2018-02-14 ...
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0  2017-10-10 ...                2017-10-18 ...
# 1  2018-08-07 ...                2018-08-13 ...
# 2  2018-08-17 ...                2018-09-04 ...
# 3  2017-12-02 ...                2017-12-15 ...
# 4  2018-02-16 ...                2018-02-26 ...
#
#  Status dos Pedidos:
# --------------------------------------------------------------------------------
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ## 📝 Checklist de Observações e Próximos Passos
#
# ### Principais Descobertas:
#
# **PAYMENTS:**
# - [X] Conferência de valores nulos
# - [X] Avaliar distribuição nos tipos de pagamento
# - [X] Verificar valores de pagamento (mínimo/máximo/média/mediana)
# - [X] Avaliar os parcelamentos realizados
#
# **ORDER_ITEMS:**
# - [X] Conferência de valores nulos
# - [X] Verificar tipo da coluna `shipping_limit_date` (provavelmente `object`, precisa converter)
# - [X] Analisar distribuição de preços e fretes
#
# **ORDERS:**
# - [ ] Converter datas para datetime, disponibilizando as operações de tempo
# - [X] Verificar valores nulos nas colunas de data
# - [X] Analisar período dos dados
# - [X] Verificar status dos pedidos
#
# ---
#
# ### Próximo Notebook:
#
# **`02_limpeza_dados.ipynb`** - Onde vamos:
# 1. Tratar valores nulos identificados
# 2. Converter colunas de data para `datetime`
# 3. Verificar e remover duplicados
# 4. Padronizar dados categóricos
# 5. Salvar CSVs limpos em `data/cleaned/pessoa_6/`
